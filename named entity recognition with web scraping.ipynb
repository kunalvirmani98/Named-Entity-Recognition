# %%
import urllib2
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5bb13d7a180b> in <module>()
# ----> 1 import urllib2
#       2 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
import urllib

# %%
from bs4 import BeautifulSoup

# %%
url="https://www.narendramodi.in/shri-narendra-modi-prime-minister-of-india-7814"

# %%
page=urllib.request.urlopen(url)

# %%
soup=BeautifulSoup(page,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <!-- STYLES -->
#   <title>
#    Shri Narendra Modi : Prime Minister of India
#   </title>
#   <meta content="On 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence. Dynamic, dedicated and determined, Narendra Modi refle" name="description"/>
#   <meta content="Awards, Biography, Governance, Development" name="keywords">
#    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#    <meta content="IE=EmulateIE7" http-equiv="X-UA-Compatible"/>
#    <meta content="google60fc0359aa00b72d.html" name="google-site-verification"/>
#    <meta content="177526890164" property="fb:pages"/>
#    <meta content="Shri Narendra Modi : Prime Minister of India" property="og:title"/>
#    <meta content="Awards, Biography, Governance, Development" property="og:keywords"/>
# ...

# %%
soup.title.string
# Out:
# 'Shri Narendra Modi : Prime Minister of India'

# %%
print(soup.article.prettify())
# Out:
# <article class="articleBody main_article_content" data-id="7814">
#  <p style="text-align: justify;">
#   On 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence.
#   <strong>
#    Dynamic, dedicated and determined, Narendra Modi reflects the aspiration and hope of over a billion Indians.
#   </strong>
#  </p>
#  <p style="text-align: justify;">
#   <strong>
#    Ever since he assumed office in May 2014, PM Modi has embarked on a journey of all-round and inclusive development where every Indian can realize their hopes and aspirations.
#   </strong>
#   He remains deeply inspired by the principle of ‘Antyodaya’, of serving the last person in the queue.
#  </p>
#  <p style="text-align: justify;">
# ...

# %%
soup.article.p
# Out:
# <p style="text-align: justify;">On 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence. <strong>Dynamic, dedicated and determined, Narendra Modi reflects the aspiration and hope of over a billion Indians.</strong></p>

# %%
print(soup.article.p.text)
# Out:
# On 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence. Dynamic, dedicated and determined, Narendra Modi reflects the aspiration and hope of over a billion Indians.

# %%
print(soup.get_text())
# Out:
# Shri Narendra Modi : Prime Minister of India
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     var JS_BASE_URL = 'https://www.narendramodi.in/';
#     var STATIC_URL = 'https://staticmain.narendramodi.in/';
#     var CLEVERTAP_ACCOUNT_ID = '4RR-W49-K84Z';
#     $(document).ready(function () {
#         var post_id = getParameterByName('post_id');
#
#         if (post_id != "") {
#             window.close();
#         }
#         var tweet_response = getParameterByName('tweet_response');
#         if (tweet_response == "success") {
#             window.close();
#         }
#         var bday = getCookie('referer_url_redirect_bday');
#         var cookieName = 'referer_url_redirect_bday';
#         if (bday == "referer_url_redirect_bday") {
#             deleteCookie(cookieName);
#             if (loggedUserEncId != '') {
#                 getbdayredirect();
#             }
#         }
#     });
#
#
# ...

# %%
print(soup.article.get_text())
# Out:
# On 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence. Dynamic, dedicated and determined, Narendra Modi reflects the aspiration and hope of over a billion Indians.
# Ever since he assumed office in May 2014, PM Modi has embarked on a journey of all-round and inclusive development where every Indian can realize their hopes and aspirations. He remains deeply inspired by the principle of ‘Antyodaya’, of serving the last person in the queue.
# Through innovative ideas and initiatives, the Government has ensured that the wheels of progress move at rapid pace and the fruits of development reach every citizen. Governance has become open, easier and transparent.
# ...

# %%
str=soup.article.get_text()

# %%
print(str)
# Out:
# On 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence. Dynamic, dedicated and determined, Narendra Modi reflects the aspiration and hope of over a billion Indians.
# Ever since he assumed office in May 2014, PM Modi has embarked on a journey of all-round and inclusive development where every Indian can realize their hopes and aspirations. He remains deeply inspired by the principle of ‘Antyodaya’, of serving the last person in the queue.
# Through innovative ideas and initiatives, the Government has ensured that the wheels of progress move at rapid pace and the fruits of development reach every citizen. Governance has become open, easier and transparent.
# ...

# %%
import nltk
import spacy
from spacy import displacy

# %%
sent_tokenized=nltk.sent_tokenize(str)

# %%
print(sent_tokenized)
# Out:
# ['\nOn 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence.', 'Dynamic, dedicated and determined, Narendra Modi reflects the aspiration and hope of over a billion Indians.', 'Ever since he assumed office in May 2014, PM Modi has embarked on a journey of all-round and inclusive development where every Indian can realize their hopes and aspirations.', 'He remains deeply inspired by the principle of ‘Antyodaya’, of serving the last person in the queue.', 'Through innovative ideas and initiatives, the Government has ensured that the wheels of progress move at rapid pace and the fruits of development reach every citizen.', 'Governance has become open, easier and transparent.', 'In a first, the Pradhan Mantri Jan Dhan Yojana marked a paradigm shift in ensuring that every citizen is integrated in the financial system of the Nation.', 'His clarion call for ‘Make in India’ complimented by a focus on maki
# ...

# %%
sent_tokenized[0]
# Out:
# '\nOn 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence.'

# %%
len(sent_tokenized)
# Out:
# 52

# %%
word_tokenized=nltk.word_tokenize(str)

# %%
word_tokenized
# Out:
# ['On',
#  '26th',
#  'May',
#  '2014',
#  'Narendra',
#  'Modi',
#  'took',
#  'oath',
#  'as',
#  'the',
#  'Prime',
#  'Minister',
#  'of',
#  'India',
#  ',',
#  'becoming',
#  'the',
#  'first',
#  'ever',
#  'PM',
#  'to',
#  'be',
#  'born',
#  'after',
#  'India',
#  'attained',
#  'Independence',
#  '.',
#  'Dynamic',
#  ',',
#  'dedicated',
#  'and',
#  'determined',
#  ',',
#  'Narendra',
#  'Modi',
#  'reflects',
#  'the',
#  'aspiration',
#  'and',
#  'hope',
#  'of',
#  'over',
#  'a',
#  'billion',
#  'Indians',
#  '.',
#  'Ever',
#  'since',
#  'he',
#  'assumed',
#  'office',
#  'in',
#  'May',
#  '2014',
#  ',',
#  'PM',
#  'Modi',
#  'has',
#  'embarked',
#  'on',
#  'a',
#  'journey',
#  'of',
#  'all-round',
#  'and',
#  'inclusive',
#  'development',
#  'where',
#  'every',
#  'Indian',
#  'can',
#  'realize',
#  'their',
#  'hopes',
#  'and',
#  'aspirations',
#  '.',
#  'He',
#  'remains',
#  'deeply',
#  'inspired',
#  'by',
#  'the',
#  'principle',
#  'of',
# ...

# %%
tagged=nltk.pos_tag(word_tokenized)

# %%
print(tagged)
# Out:
# [('On', 'IN'), ('26th', 'CD'), ('May', 'NNP'), ('2014', 'CD'), ('Narendra', 'NNP'), ('Modi', 'NNP'), ('took', 'VBD'), ('oath', 'RP'), ('as', 'IN'), ('the', 'DT'), ('Prime', 'NNP'), ('Minister', 'NNP'), ('of', 'IN'), ('India', 'NNP'), (',', ','), ('becoming', 'VBG'), ('the', 'DT'), ('first', 'JJ'), ('ever', 'RB'), ('PM', 'NNP'), ('to', 'TO'), ('be', 'VB'), ('born', 'VBN'), ('after', 'IN'), ('India', 'NNP'), ('attained', 'VBD'), ('Independence', 'NNP'), ('.', '.'), ('Dynamic', 'NNP'), (',', ','), ('dedicated', 'VBN'), ('and', 'CC'), ('determined', 'VBN'), (',', ','), ('Narendra', 'NNP'), ('Modi', 'NNP'), ('reflects', 'VBZ'), ('the', 'DT'), ('aspiration', 'NN'), ('and', 'CC'), ('hope', 'NN'), ('of', 'IN'), ('over', 'IN'), ('a', 'DT'), ('billion', 'CD'), ('Indians', 'NNPS'), ('.', '.'), ('Ever', 'RB'), ('since', 'IN'), ('he', 'PRP'), ('assumed', 'VBD'), ('office', 'NN'), ('in', 'IN'), ('May', 'NNP'), ('2014', 'CD'), (',', ','), ('PM', 'NNP'), ('Modi', 'NNP'), ('has', 'VBZ'), ('embarked',
# ...

# %%
str
# Out:
# '\nOn 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence. Dynamic, dedicated and determined, Narendra Modi reflects the aspiration and hope of over a billion Indians.\nEver since he assumed office in May 2014, PM Modi has embarked on a journey of all-round and inclusive development where every Indian can realize their hopes and aspirations. He remains deeply inspired by the principle of ‘Antyodaya’, of serving the last person in the queue.\nThrough innovative ideas and initiatives, the Government has ensured that the wheels of progress move at rapid pace and the fruits of development reach every citizen. Governance has become open, easier and transparent.\nIn a first, the Pradhan Mantri Jan Dhan Yojana marked a paradigm shift in ensuring that every citizen is integrated in the financial system of the Nation. His clarion call for ‘Make in India’ complimented by a focus on making business easy ha
# ...

# %%
import en_core_web_sm

# %%
nlp=en_core_web_sm.load()

# %%
doc=nlp(str)

# %%
doc
# Out:
# On 26th May 2014 Narendra Modi took oath as the Prime Minister of India, becoming the first ever PM to be born after India attained Independence. Dynamic, dedicated and determined, Narendra Modi reflects the aspiration and hope of over a billion Indians.
# Ever since he assumed office in May 2014, PM Modi has embarked on a journey of all-round and inclusive development where every Indian can realize their hopes and aspirations. He remains deeply inspired by the principle of ‘Antyodaya’, of serving the last person in the queue.
# Through innovative ideas and initiatives, the Government has ensured that the wheels of progress move at rapid pace and the fruits of development reach every citizen. Governance has become open, easier and transparent.
# ...

# %%
displacy.render(doc,style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# On
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     26th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# ...
